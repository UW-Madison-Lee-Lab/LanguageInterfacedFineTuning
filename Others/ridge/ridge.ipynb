# %%
from ridge import *
import sys, os
import matplotlib.pyplot as plt
sys.path.insert(1, '../../regression/utils')

# %%
run_setting_gptj(['data_1', 'data_2', 'data_3'],  cuda_idx = 2)

# %%
run_setting_gpt3('data_2',  
                 openai_key = '[REPLACE IT WITH YOUR OPENAI KEY]') # , lbd_list = [0], lr_list = [0.05]
# Out:
# ------------------Runing group 1---------------------
# Save a file at: data_2/linear_lbd_0_n_250_p_1_int_0_(-10.0,10.0)_noise_0.00_train.jsonl
# Save a file at: data_2/linear_lbd_0_n_250_p_1_int_0_(-10.0,10.0)_noise_0.00_valid.jsonl
# train file saved at: data_2/linear_lbd_0_n_250_p_1_int_0_(-10.0,10.0)_noise_0.00_train.jsonl
# validation file saved at: data_2/linear_lbd_0_n_250_p_1_int_0_(-10.0,10.0)_noise_0.00_valid.jsonl
# ==== Learning rate multiplier 0.0500 ====
# | pending
# | running
# | succeeded
# | fine-tune id:  ft-ESM6HKeDdPH7RLn1xkxaWvYP
# | fine-tune model:  ada:ft-university-of-wisconsin-madison-2022-05-05-06-13-35
# | Valid #outputs/Total #outputs:50/50
# | RMSE     : 0.0055
# | RMSE(woo): 0.0055   #outlier:  0}
# ==== Learning rate multiplier 0.1000 ====
# | running
# | succeeded
# | fine-tune id:  ft-3ZWdli8Czh4AmB1NjWcHDwzR
# | fine-tune model:  ada:ft-university-of-wisconsin-madison-2022-05-05-06-16-46
# | Valid #outputs/Total #outputs:50/50
# ...

# %%
run_setting_gpt3('data_3',  
                 openai_key = '[REPLACE IT WITH YOUR OPENAI KEY]') # , lbd_list = [0], lr_list = [0.05]

# %%
train = data[0]
X_train = train[0].values

# %%
y_train = train['y'].values

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train.reshape(101,1), y_train)
# Out:
# LinearRegression()

# %%
y = lm.predict(data[8])

# %%
ax = pd.DataFrame({'x': data[8].reshape(-1), 'y': y}).plot(x = 'x', y = 'y')
ax.plot(data[8].reshape(-1), data[9].reshape(-1))
