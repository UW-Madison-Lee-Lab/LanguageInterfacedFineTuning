# %%
import sys, os, json
sys.path.insert(1, '../utils')
from run_exp import *

# %%
# run 1
run_setting_gpt3('data',
                n_sims = 3,
                n_train = 200, 
                n_valid = 50, 
                n_test = 100, 
                data_list = ["linear", "piecewise"],
                p_list=[1], 
                lb_ub_list = [(-150,150)],
                integer_list = [False],
                noise_level_list = [0.1],
                num_epochs = 10, 
                batch_size = 5,
                resolution = 2, openai_key = '[REPLACE IT WITH YOUR OPENAI KEY]')
# Out:
# ------------------Runing group 1---------------------
# p=1,dataset=linear,integer=False,range=[-150,150]
# ---Simulation 1---
# Save a file at: data/data_1/linear_n_250_p_1_int_0_(-150.0,150.0)_noise_0.10_train.jsonl
# Save a file at: data/data_1/linear_n_250_p_1_int_0_(-150.0,150.0)_noise_0.10_valid.jsonl
# train file saved at: data/data_1/linear_n_250_p_1_int_0_(-150.0,150.0)_noise_0.10_train.jsonl
# validation file saved at: data/data_1/linear_n_250_p_1_int_0_(-150.0,150.0)_noise_0.10_valid.jsonl
# ==== Learning rate multiplier 0.0500 ====
# | pending
# | running
# | succeeded
# | fine-tune id:  ft-zjAdcgYErS49AA9zdKhfglgm
# | fine-tune model:  ada:ft-university-of-wisconsin-madison-2022-06-05-19-31-35
# | Valid #outputs/Total #outputs:50/50
# | RMSE     : 9.4152
# | RMSE(woo): 9.4152   #outlier:  0}
# ==== Learning rate multiplier 0.1000 ====
# | pending
# | running
# | succeeded
# | fine-tune id:  ft-jyDunZhBGnUsHhOPTXdA0Ahb
# ...

# %%
# run 2
run_setting_gpt3('data',
                n_sims = 3,
                n_train = 200, 
                n_valid = 50, 
                n_test = 100, 
                data_list = ["linear", "piecewise"],
                p_list=[1], 
                lb_ub_list = [(-150,150)],
                integer_list = [True],
                noise_level_list = [0.1],
                num_epochs = 10, 
                batch_size = 5,
                resolution = 2, openai_key = '[REPLACE IT WITH YOUR OPENAI KEY]')

# %%
# run 3
run_setting_gpt3('data',
                n_sims = 3,
                n_train = 200, 
                n_valid = 50, 
                n_test = 100, 
                data_list = ["linear", "piecewise"],
                p_list=[1], 
                lb_ub_list = [(0,300)],
                integer_list = [True],
                noise_level_list = [0.1],
                num_epochs = 10, 
                batch_size = 5,
                resolution = 2, openai_key = '[REPLACE IT WITH YOUR OPENAI KEY]')

# %%
# run 4
run_setting_gpt3('data',
                n_sims = 3,
                n_train = 200, 
                n_valid = 50, 
                n_test = 100, 
                data_list = ["linear", "piecewise"],
                p_list=[1], 
                lb_ub_list = [(0,300)],
                integer_list = [False],
                noise_level_list = [0.1],
                num_epochs = 10, 
                batch_size = 5,
                resolution = 2, openai_key = '[REPLACE IT WITH YOUR OPENAI KEY]')

# %%
# running 1
run_setting_gptj('data',
                n_sims = 3,
                n_train = 200, 
                n_valid = 50, 
                n_test = 100, 
                data_list = ["linear", "piecewise"],
                p_list=[1], 
                lb_ub_list = [(-150,150)],
                integer_list = [False],
                noise_level_list = [0.1],
                cuda_idx = 0)
# Out:
# ------------------Runing group 1---------------------
# p=1,dataset=linear,integer=False,range=[-150,150]
# ---Simulation 1---
# ==== Epoch 2.0000 ====
# ...
# Validation: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:01<00:00,  6.69it/s, val_loss=1.82]
# | Valid #outputs/Total #outputs:50/50
# | RMSE     : 10.0676
# | RMSE(woo): 10.0676   #outlier:  0}
# Valid #outputs/Total #outputs:100/100
# ==== Epoch 6.0000 ====
# ...
# Validation: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:01<00:00,  6.67it/s, val_loss=2.51]
# | Valid #outputs/Total #outputs:50/50
# | RMSE     : 10.6771
# | RMSE(woo): 10.6771   #outlier:  0}
# Valid #outputs/Total #outputs:100/100
# ==== Epoch 10.0000 ====
# ...

# %%
# todo 2
run_setting_gptj('data',
                n_sims = 3,
                n_train = 200, 
                n_valid = 50, 
                n_test = 100, 
                data_list = ["linear", "piecewise"],
                p_list=[1], 
                lb_ub_list = [(-150,150)],
                integer_list = [True],
                noise_level_list = [0.1],
                cuda_idx = 0)

# %%
# todo 3
run_setting_gptj('data',
                n_sims = 3,
                n_train = 200, 
                n_valid = 50, 
                n_test = 100, 
                data_list = ["linear", "piecewise"],
                p_list=[1], 
                lb_ub_list = [(0,300)],
                integer_list = [True],
                noise_level_list = [0.1],
                cuda_idx = 0)
# Out:
# ------------------Runing group 1---------------------
# p=1,dataset=linear,integer=True,range=[0,300]
# ---Simulation 1---
# ==== Epoch 2.0000 ====
# ...
# Validation: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:01<00:00,  6.57it/s, val_loss=1.17]
# | Valid #outputs/Total #outputs:50/50
# | RMSE     : 10.2333
# | RMSE(woo): 10.2333   #outlier:  0}
# Valid #outputs/Total #outputs:100/100
# ==== Epoch 6.0000 ====
# ...
# Validation: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:01<00:00,  6.79it/s, val_loss=1.63]
# | Valid #outputs/Total #outputs:50/50
# | RMSE     : 9.5885
# | RMSE(woo): 9.5885   #outlier:  0}
# Valid #outputs/Total #outputs:100/100
# ==== Epoch 10.0000 ====
# ...

# %%
# todo 3
run_setting_gptj('data',
                n_sims = 3,
                n_train = 200, 
                n_valid = 50, 
                n_test = 100, 
                data_list = ["linear", "piecewise"],
                p_list=[1], 
                lb_ub_list = [(0,300)],
                integer_list = [False],
                noise_level_list = [0.1],
                cuda_idx = 0)
# Out:
# ------------------Runing group 1---------------------
# p=1,dataset=linear,integer=False,range=[0,300]
# ---Simulation 1---
# ==== Epoch 2.0000 ====
# ...
# Validation: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:01<00:00,  6.69it/s, val_loss=2.08]
# | Valid #outputs/Total #outputs:50/50
# | RMSE     : 12.7363
# | RMSE(woo): 12.7363   #outlier:  0}
# Valid #outputs/Total #outputs:100/100
# ==== Epoch 6.0000 ====
# ...
# Validation: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [00:01<00:00,  6.69it/s, val_loss=3.2]
# | Valid #outputs/Total #outputs:50/50
# | RMSE     : 12.5564
# | RMSE(woo): 12.5564   #outlier:  0}
# Valid #outputs/Total #outputs:100/100
# ==== Epoch 10.0000 ====
# ...

# %%
from resultsCollector import *

# %%
file_list = []
for sim_idx in range(1,4):
    data_dir = 'data/data_%d' % sim_idx
    for file in os.listdir(data_dir):
        if file.endswith('all.json') and (file.startswith('linear') or file.startswith('piecewise')):
            file_list.append('%s/%s' % (data_dir, file))

# %%
file_list
# Out:
# ['data/data_1/piecewise_n_250_p_1_int_0_(-150.0,150.0)_noise_0.10_all.json',
#  'data/data_1/linear_n_250_p_1_int_1_(0.0,300.0)_noise_0.10_all.json',
#  'data/data_1/piecewise_n_250_p_1_int_1_(0.0,300.0)_noise_0.10_all.json',
#  'data/data_1/linear_n_250_p_1_int_0_(0.0,300.0)_noise_0.10_all.json',
#  'data/data_1/piecewise_n_250_p_1_int_0_(0.0,300.0)_noise_0.10_all.json',
#  'data/data_1/piecewise_n_250_p_1_int_1_(-150.0,150.0)_noise_0.10_all.json',
#  'data/data_1/linear_n_250_p_1_int_1_(-150.0,150.0)_noise_0.10_all.json',
#  'data/data_1/linear_n_250_p_1_int_0_(-150.0,150.0)_noise_0.10_all.json',
#  'data/data_2/piecewise_n_250_p_1_int_0_(-150.0,150.0)_noise_0.10_all.json',
#  'data/data_2/linear_n_250_p_1_int_1_(0.0,300.0)_noise_0.10_all.json',
#  'data/data_2/piecewise_n_250_p_1_int_1_(0.0,300.0)_noise_0.10_all.json',
#  'data/data_2/linear_n_250_p_1_int_0_(0.0,300.0)_noise_0.10_all.json',
#  'data/data_2/piecewise_n_250_p_1_int_0_(0.0,300.0)_noise_0.10_all.json',
# ...

# %%
collect_data_json(file_list, metric = 'RAE', grid_loss = False, gpt3 = True, gptj = True, baseline = True, grid_compute = False)
# Out:
# ----------------------------1------------------------------
# file path:  data/data_1/piecewise_n_250_p_1_int_0_(-150.0,150.0)_noise_0.10_all.json
# PR RAE: 0.02
# KRR RAE: 0.12
# KNN RAE: 0.03
# /home/user0/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# NN RAE: 0.07
# XG RAE: 0.04
# RF RAE: 0.04
# GP RAE: 0.79
# Valid #outputs/Total #outputs:100/100
# RAE     : 0.0733
# RAE(woo): 0.0717   #outlier:  1}
# GPTJ RAE: 0.0710
# ----------------------------2------------------------------
# file path:  data/data_1/linear_n_250_p_1_int_1_(0.0,300.0)_noise_0.10_all.json
# PR RAE: 0.01
# KRR RAE: 0.18
# KNN RAE: 0.03
# ...

# %%
for sim_idx in range(1,4):
    save_csv(
        ['data/data_%d/piecewise_n_250_p_1_int_0_(-150.0,150.0)_noise_0.10_all.json' % sim_idx,
        'data/data_%d/linear_n_250_p_1_int_1_(0.0,300.0)_noise_0.10_all.json' % sim_idx,
        'data/data_%d/piecewise_n_250_p_1_int_1_(0.0,300.0)_noise_0.10_all.json' % sim_idx,
        'data/data_%d/linear_n_250_p_1_int_0_(0.0,300.0)_noise_0.10_all.json' % sim_idx,
        'data/data_%d/piecewise_n_250_p_1_int_0_(0.0,300.0)_noise_0.10_all.json' % sim_idx,
        'data/data_%d/piecewise_n_250_p_1_int_1_(-150.0,150.0)_noise_0.10_all.json' % sim_idx,
        'data/data_%d/linear_n_250_p_1_int_1_(-150.0,150.0)_noise_0.10_all.json' % sim_idx,
        'data/data_%d/linear_n_250_p_1_int_0_(-150.0,150.0)_noise_0.10_all.json'% sim_idx], 
        'data/data_%d/all_models_acc%d.csv' % (sim_idx, sim_idx)
    )
# Out:
# ----------------------------1------------------------------
# file path:  data/data_1/piecewise_n_250_p_1_int_0_(-150.0,150.0)_noise_0.10_all.json
# ----------------------------2------------------------------
# file path:  data/data_1/linear_n_250_p_1_int_1_(0.0,300.0)_noise_0.10_all.json
# ----------------------------3------------------------------
# file path:  data/data_1/piecewise_n_250_p_1_int_1_(0.0,300.0)_noise_0.10_all.json
# ----------------------------4------------------------------
# file path:  data/data_1/linear_n_250_p_1_int_0_(0.0,300.0)_noise_0.10_all.json
# ----------------------------5------------------------------
# file path:  data/data_1/piecewise_n_250_p_1_int_0_(0.0,300.0)_noise_0.10_all.json
# ----------------------------6------------------------------
# file path:  data/data_1/piecewise_n_250_p_1_int_1_(-150.0,150.0)_noise_0.10_all.json
# ----------------------------7------------------------------
# ...

# %%
get_mean_std_syn('data')

# %%
print_overleaf_basic('data', manipulate = 'input type', report_func = ['linear', 'piecewise'])
# Out:
# \begin{table}[]
# \begin{center}
# \begin{small}
# \begin{sc}
# \tiny{
# \begin{tabularx}{0.9\textwidth}{llccccccc}
# \toprule
# Method & \gptt{} & \gptj{} & \qr{} & \krr{} & \knn{}  & \ann{} & \xg{} & rf{} \\
#   & $\gX$ & RAE  & RAE  & RAE  &  RAE &  RAE  &  RAE &  RAE & RAE \\ \midrule
#         \multirow{4}{*}{\expo{}} & $\sR$& $0.01 \pm 0.0$ & $0.11 \pm 0.0$ & $0.03 \pm 0.0$ & $0.01 \pm 0.0$ & $0.05 \pm 0.0$ & $0.04 \pm 0.0$ & $0.71 \pm 0.0$ & $0.07 \pm 0.0$ & $0.07 \pm 0.0$ \\
# & $\sR^+$& $0.01 \pm 0.0$ & $0.19 \pm 0.0$ & $0.04 \pm 0.0$ & $0.01 \pm 0.0$ & $0.05 \pm 0.0$ & $0.04 \pm 0.0$ & $1.01 \pm 0.2$ & $0.08 \pm 0.0$ & $0.08 \pm 0.0$ \\
# & $\sZ$& $0.01 \pm 0.0$ & $0.11 \pm 0.0$ & $0.03 \pm 0.0$ & $0.01 \pm 0.0$ & $0.04 \pm 0.0$ & $0.04 \pm 0.0$ & $0.58 \pm 0.0$ & $0.07 \pm 0.0$ & $0.08 \pm 0.0$ \\
# & $\sZ^+$& $0.01 \pm 0.0$ & $0.18 \pm 0.0$ & $0.03 \pm 0.0$ & $0.01 \pm 0.0$ & $0.04 \pm 0.0$ & $0.04 \pm 0.0$ & $0.50 \pm 0.6$ & $0.07 \pm 0.0$ & $0.08 \pm 0.0$ \\
# ...
