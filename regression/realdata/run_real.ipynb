# %%
from run_real import run_setting_gpt3
from run_real import run_setting_gptj

# %%
# run 436
from run_real import run_setting_gptj
run_setting_gptj('results', 
                 data_list = ['insurance'],
                 pc_list = ['20', '40', '60'],
                prefix_list = ['=fn='],
                batch_size = 4,
                cuda_idx = 0
)
# Out:
# Failure: OpenAI module is not loaded!
# Failure: OpenAI module is not loaded!
# ------------------Runing group 0---------------------
# insurance=fn=20
# ---Simulation 1---
# ==== Epoch 2.0000 ====
# ...
# Validation: 100%|██████████| 51/51 [00:18<00:00,  2.71it/s, val_loss=2.8]
# | Valid #outputs/Total #outputs:201/201
# | RMSE     : 15824.7592
# | RMSE(woo): 15824.7592   #outlier:  0}
# Valid #outputs/Total #outputs:201/201
# ==== Epoch 6.0000 ====
# ...
# Validation: 100%|██████████| 51/51 [00:18<00:00,  2.71it/s, val_loss=3.93]
# | Valid #outputs/Total #outputs:201/201
# | RMSE     : 16169.4394
# | RMSE(woo): 16169.4394   #outlier:  0}
# Valid #outputs/Total #outputs:201/201
# ==== Epoch 10.0000 ====
# ...
# Validation: 100%|██████████| 51/51 [00:18<00:00,  2.69it/s, val_loss=7.44]
# | Valid #outputs/Total #outputs:201/201
# | RMSE     : 14387.0434
# | RMSE(woo): 14387.0434   #outlier:  0}
# Valid #outputs/Total #outputs:201/201
# Selected epoch: 10.0000
# ---Simulation 2---
# ...

# %%
# run 444
from run_real import run_setting_gptj
run_setting_gptj('results', 
                 data_list = ['insurance'],
                 pc_list = ['20', '40', '60'],
                prefix_list = ['_rd_'],
                batch_size = 4,
                cuda_idx = 0
)

# %%
# runn 435
from run_real import run_setting_gptj
run_setting_gptj('results', 
                 data_list = ['insurance'],
                 pc_list = ['80', 'full', ],
                prefix_list = ['_rd_'],
                batch_size = 4,
                cuda_idx = 0
)

# %%
# run 444
from run_real import run_setting_gptj
run_setting_gptj('results', 
                 data_list = ['insurance'],
                 pc_list = ['80'],
                prefix_list = ['=fn='],
                batch_size = 4,
                cuda_idx = 0
)

# %%
# running 444
from run_real import run_setting_gptj
run_setting_gptj('results', 
                 data_list = ['insurance'],
                 pc_list = ['full'],
                prefix_list = ['=fn='],
                batch_size = 4,
                cuda_idx = 0
)

# %%
# running 435
from run_real import run_setting_gptj
run_setting_gptj('results', 
                 data_list = ['insurance'],
                 pc_list = ['20', '40', '60'], # , '80', 'full'
                prefix_list = ['=rd='],
                batch_size = 4,
                cuda_idx = 0
)

# %%
# running 436
from run_real import run_setting_gptj
run_setting_gptj('results', 
                 data_list = ['insurance'],
                 pc_list = ['80', 'full'], 
                prefix_list = ['=rd='],
                batch_size = 4,
                cuda_idx = 0
)

# %%
# run
from run_real import run_setting_gpt3
run_setting_gpt3('results', 
                 openai_key = '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', 
                 data_list = ['insurance'],
                 pc_list = ['20', '40', '60', '80'],
                prefix_list = ['=rd=']
)

# %%
# run
from run_real import run_setting_gpt3
run_setting_gpt3('results', 
                 openai_key = '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', 
                 data_list = ['insurance'],
                 pc_list = ['20', '40', '60'],
                prefix_list = ['_rd_']
)

# %%
# run
from run_real import run_setting_gpt3
run_setting_gpt3('results', 
                 openai_key = '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', 
                 data_list = ['insurance'],
                 pc_list = ['80', 'full'],
                prefix_list = ['_rd_']
)

# %%
# run
from run_real import run_setting_gpt3
run_setting_gpt3('results', 
                 openai_key = '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', 
                 data_list = ['insurance'],
                 pc_list = ['20', '40', '60', '80'],
                prefix_list = ['=fn=']
)

# %%
# run
from run_real import run_setting_gpt3
run_setting_gpt3('results', 
                 openai_key = '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', 
                 data_list = ['insurance'],
                 pc_list = ['full'],
                prefix_list = ['=fn=', '=rd=']
)

# %%
# cancel
run_setting_gpt3('results', 
                 openai_key = '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', 
                 data_list = ['diamond'],
                prefix_list = ['_fn_'])
# Out:
# ------------------Runing group 0---------------------
# diamond_fn_20
# ---Simulation 1---
# ==== Learning rate multiplier 0.0500 ====
# | pending
# | running
# | succeeded
# | fine-tune id:  ft-CY00nzuhwjBsdXyUte8yZSrE
# | fine-tune model:  ada:ft-university-of-wisconsin-madison-2022-05-12-19-54-23
# | Valid #outputs/Total #outputs:8091/8091
# | RMSE     : 1453.4771
# | RMSE(woo): 871.8325   #outlier:  2}
# ==== Learning rate multiplier 0.1000 ====
# | running
# | succeeded
# | fine-tune id:  ft-My3sPVlvarr6NQ1LFgyxx8au
# | fine-tune model:  ada:ft-university-of-wisconsin-madison-2022-05-12-21-57-10
# | Valid #outputs/Total #outputs:8091/8091
# | RMSE     : 872.8452
# | RMSE(woo): 872.8452   #outlier:  0}
# ==== Learning rate multiplier 0.2000 ====
# | running
# | succeeded
# | fine-tune id:  ft-Zx1uTPD1LkI0QRIAZh899pvg
# | fine-tune model:  ada:ft-university-of-wisconsin-madison-2022-05-12-23-47-40
# | Valid #outputs/Total #outputs:8091/8091
# | RMSE     : 1569.9074
# ...

# %%
# 
run_setting_gptj('results', 
                 data_list = ['diamond'],
                 pc_list = ['20'],
                prefix_list = ['_fn_'],
                cuda_idx = 3)

# %%
# running
run_setting_gpt3('results', 
                 data_list = ['student'],
                 pc_list = ['20', '40', '60'],
                prefix_list = ['_fn_', '_'],
                openai_key = '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')
# Out:
# ------------------Runing group 0---------------------
# student_fn_20
# ---Simulation 1---
# ==== Learning rate multiplier 0.0500 ====
# | pending
# | running
# | succeeded
# | fine-tune id:  ft-iRhm4kF3ABSD3i51vxHZuayu
# | fine-tune model:  ada:ft-university-of-wisconsin-madison-2022-05-14-08-07-58
# | Valid #outputs/Total #outputs:97/97
# | RMSE     : 1.4538
# | RMSE(woo): 1.4538   #outlier:  0}
# ==== Learning rate multiplier 0.1000 ====
# | pending
# | running
# | succeeded
# | fine-tune id:  ft-hgWlD2XIqNVYAzUmg7bg5cWf
# | fine-tune model:  ada:ft-university-of-wisconsin-madison-2022-05-14-08-15-07
# | Valid #outputs/Total #outputs:97/97
# | RMSE     : 1.4466
# | RMSE(woo): 1.4466   #outlier:  0}
# ==== Learning rate multiplier 0.2000 ====
# | pending
# | running
# | succeeded
# | fine-tune id:  ft-XfkagFtVIyHiD82oBa8iTxPd
# | fine-tune model:  ada:ft-university-of-wisconsin-madison-2022-05-14-08-23-14
# | Valid #outputs/Total #outputs:97/97
# | RMSE     : 1.5432
# ...

# %%
# run
run_setting_gpt3('results', 
                 data_list = ['student'],
                 pc_list = ['80', 'full'],
                prefix_list = ['_fn_'],
                openai_key = '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')

# %%
# run
run_setting_gpt3('results', 
                 data_list = ['student'],
                 pc_list = ['80', 'full'],
                prefix_list = ['_'],
                openai_key = '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')

# %%
# run
run_setting_gptj('results', 
                 data_list = ['student'],
                 pc_list = ['40', '60', '80'],
                prefix_list = ['_fn_'],
                cuda_idx = 2,
                batch_size = 1)

# %%
# run
run_setting_gptj('results', 
                 data_list = ['student'],
                 pc_list = ['20', 'full'],
                prefix_list = ['_fn_'],
                cuda_idx = 2,
                batch_size = 1)

# %%
# run
run_setting_gptj('results', 
                 data_list = ['student'],
                 pc_list = ['20', '40', '60', '80', 'full'],
                prefix_list = ['_'],
                cuda_idx = 2,
                batch_size = 1)

# %%
# run
run_setting_gptj('results', 
                 data_list = ['servo'],
                cuda_idx = 0)

# %%
# run
run_setting_gptj('results', 
                 data_list = ['insurance'],
                 pc_list = ['20'],
                 prefix_list = ['_'],
                cuda_idx = 2)

# %%
# run
run_setting_gptj('results', 
                 data_list = ['insurance'],
                 pc_list = ['20'],
                 prefix_list = ['_fn_'],
                cuda_idx = 2)

# %%
# run
run_setting_gptj('results', 
                 data_list = ['insurance'],
                 pc_list = ['40', '60', 'full'],
                cuda_idx = 2)

# %%
# running
run_setting_gptj('results', 
                 data_list = ['insurance'],
                 pc_list = ['80'],
                cuda_idx = 2)

# %%
# run
run_setting_gptj('results', 
                 data_list = ['ccpp'],
                 prefix_list = ['_fn_'],
                 pc_list = ['20', '40', '60'],
                cuda_idx = 1)

# %%
# run
run_setting_gptj('results', 
                 data_list = ['ccpp'],
                 prefix_list = ['_'],
                 pc_list = ['40', '60'],
                cuda_idx = 0)

# %%
# run
run_setting_gptj('results', 
                 data_list = ['ccpp'],
                 prefix_list = ['_'],
                 pc_list = ['20'],
                cuda_idx = 0)

# %%
# run
run_setting_gptj('results', 
                 data_list = ['ccpp'],
                 prefix_list = ['_'],
                 pc_list = ['80'],
                cuda_idx = 1)

# %%
# run
run_setting_gptj('results', 
                 data_list = ['ccpp'],
                 prefix_list = ['_'],
                 pc_list = ['full'],
                cuda_idx = 2)

# %%
# run
run_setting_gptj('results', 
                 data_list = ['ccpp'],
                 prefix_list = ['_fn_'],
                 pc_list = ['full'],
                cuda_idx = 3)

# %%
# run
run_setting_gptj('results', 
                 data_list = ['ccpp'],
                 prefix_list = ['_fn_'],
                 pc_list = ['80'],
                cuda_idx = 3)

# %%
# cancel
run_setting_gpt3('results', 
                 openai_key = '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', 
                 data_list = ['diamond'],
                 pc_list = ['40'],
                prefix_list = ['_'])

# %%
# cancel
run_setting_gpt3('results', 
                 openai_key = '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', 
                 data_list = ['diamond'],
                 pc_list = ['60'],
                prefix_list = ['_'])

# %%
# cancel
run_setting_gpt3('results', 
                 openai_key = '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', 
                 data_list = ['diamond'],
                 pc_list = ['80', 'full'],
                prefix_list = ['_'])

# %%
# run
run_setting_gpt3('results', 
                 openai_key = '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', 
                 data_list = ['diamond'],
                 pc_list = ['20'],
                prefix_list = ['_'])

# %%
# cancel
run_setting_gptj('results', 
                 data_list = ['diamond'],
                 prefix_list = ['_'],
                 pc_list = ['20'],
                cuda_idx = 0)

# %%
# run
run_setting_gpt3('results', 
                 openai_key = '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', 
                 data_list = ['insurance'])

# %%
# run
run_setting_gpt3('results', 
                 openai_key = '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', 
                 data_list = ['servo'])

# %%
# run
run_setting_gpt3('results', 
                 openai_key = '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', 
                 data_list = ['CCPP'],
                 prefix_list = ['_fn_']
                )
# Out:
# ------------------Runing group 0---------------------
# ccpp_fn_20
# ---Simulation 1---
# ==== Learning rate multiplier 0.0500 ====
# | pending
# | running
# | succeeded
# | fine-tune id:  ft-bQN5BCaRCwJEZvsKmIz6dY4R
# | fine-tune model:  ada:ft-university-of-wisconsin-madison-2022-05-11-03-57-43
# | Valid #outputs/Total #outputs:1435/1435
# | RMSE     : 9.2774
# | RMSE(woo): 4.6219   #outlier:  1}
# ==== Learning rate multiplier 0.1000 ====
# | running
# | succeeded
# | fine-tune id:  ft-3JIbScMchHDKRDEyOCow9wlZ
# | fine-tune model:  ada:ft-university-of-wisconsin-madison-2022-05-11-04-47-57
# That model is still being loaded. Please try again shortly.
# That model is still being loaded. Please try again shortly.
# | Valid #outputs/Total #outputs:1435/1435
# | RMSE     : 11.8937
# | RMSE(woo): 4.8194   #outlier:  1}
# ==== Learning rate multiplier 0.2000 ====
# | running
# | succeeded
# | fine-tune id:  ft-tUCPngTIgyN5oID5MxkCDcxd
# ...

# %%
# run
run_setting_gpt3('results', 
                 openai_key = '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', 
                 data_list = ['CCPP'],
                 prefix_list = ['_fn_'],
                 pc_list = ['80', 'full']
                )
